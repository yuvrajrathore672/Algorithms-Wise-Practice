# %%
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import accuracy_score , precision_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("C:/Users/gokup/Downloads/heart (1).csv")
df.sample(5)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 160   56    1   1       120   240    0        1      169      0      0.0
# 114   55    1   1       130   262    0        1      155      0      0.0
# 187   54    1   0       124   266    0        0      109      1      2.2
# 92    52    1   2       138   223    0        1      169      0      0.0
# 109   50    0   0       110   254    0        0      159      0      0.0
#
#      slope  ca  thal  target
# 160      0   0     2       1
# 114      2   0     2       1
# 187      1   1     3       0
# 92       2   4     2       1
# 109      2   0     2       1

# %%
y = df["target"]
x = df.drop("target",axis=1)

# %%
x_train ,x_test ,y_train, y_test = train_test_split(
    x,y,random_state=42,test_size=0.2
)

# %%
y_train[y_train==1]  #133
y_train[y_train==0]  #109
# Out:
# 202    0
# 196    0
# 176    0
# 177    0
# 258    0
#       ..
# 257    0
# 214    0
# 302    0
# 188    0
# 270    0
# Name: target, Length: 109, dtype: int64

# %%
model1 = LogisticRegression(max_iter=1500)
model1.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1500)

# %%
pred = model1.predict(x_test)

# %%
print("accuracyscore:",accuracy_score(y_test,pred))
print("precisionscore:",precision_score(y_test,pred))
print("recallscore:",recall_score(y_test,pred)) 
print("f1score:",f1_score(y_test,pred))
# Out:
# accuracyscore: 0.8852459016393442
# precisionscore: 0.8787878787878788
# recallscore: 0.90625
# f1score: 0.8923076923076924

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model2 = LogisticRegression(max_iter=2000)
model2.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=2000)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score , precision_score , f1_score
y_pre = model2.predict(x_test)
acc = accuracy_score(y_test,y_pre)
acc
# Out:
# 0.8524590163934426

# %%
print(confusion_matrix(y_test,y_pre))
# Out:
# [[25  4]
#  [ 5 27]]

# %%
print("accuracyscore:",accuracy_score(y_test,y_pre))
print("precisionscore:",precision_score(y_test,y_pre))
print("recallscore:",recall_score(y_test,y_pre)) 
print("f1score:",f1_score(y_test,y_pre))
# Out:
# accuracyscore: 0.8524590163934426
# precisionscore: 0.8709677419354839
# recallscore: 0.84375
# f1score: 0.8571428571428571
